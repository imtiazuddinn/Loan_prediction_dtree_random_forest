# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/loan_data.csv')

# %% [markdown]
# **LOAN PREDICTION PROBLEM**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/loan_data.csv')

# %% [markdown]
# **Checking the head(), info() and describe() methods on the dataset**

# %%
data.head(4)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0
# 2            0        0               0
# 3            0        0               0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **FICO DISTRIBUTUTIONS ONE FOR EACH CREDIT POLICY**

# %%
plt.figure(figsize=(8,4))
data[data['credit.policy']==1]['fico'].plot.hist(bins=35,color='blue',label='Credit Policy=1',alpha=0.6)
data[data['credit.policy']==0]['fico'].plot.hist(bins=35,color='green',label='Credit Policy=2',alpha=0.6)
plt.legend()
plt.xlabel('Fico')
plt.show()

# %% [markdown]
# **FICO DISTRIBUTUTIONS BY NOT.FULLY.PAID COLUMN**

# %%
 plt.figure(figsize=(8,4))
 data[data['not.fully.paid']==0]['fico'].hist(bins=35,color='green',label='not.fully.paid=0',alpha=0.6)
 data[data['not.fully.paid']==1]['fico'].hist(bins=35,color='yellow',label='not.fully.paid=1',alpha=0.6)
 plt.legend()
 plt.xlabel('fico')
 plt.show()

# %% [markdown]
# **VISUALIZING COUNTS OF LOANS BY PURPOSE**

# %%
plt.figure(figsize=(9,4))
sns.countplot(x='purpose',hue='not.fully.paid',data=data)
plt.tight_layout()
plt.show()

# %% [markdown]
# **VISUALIZING TREND BETWEEN FICO AND INTEREST RATE **

# %%
sns.jointplot(x='fico',y='int.rate',data=data)

# %% [markdown]
# **LMPLOTS TO CHECK IF THERE IS A TREND BETWEEN NOT.FULLY.PAID AND CREDIT.POLICY**

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='int.rate',y='fico',data=data,hue='credit.policy',col='not.fully.paid', palette='Set1')

# %% [markdown]
# **SETTING UP THE DATA**

# %%
final_data=pd.get_dummies(data,columns=['purpose'],drop_first=True)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %% [markdown]
# **TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(final_data.drop('not.fully.paid',axis=1),final_data['not.fully.paid'],test_size=0.3,random_state=42)

# %% [markdown]
# **TRAINING A DECISION TREE CLASSIFIER**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **predictions and evaluations of decision tree**

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      2408
#            1       0.19      0.20      0.19       466
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.74      0.73      0.73      2874
#
# [[2011  397]
#  [ 373   93]]

# %% [markdown]
# **Training a Random Forest Model **

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred_rfc=rfc.predict(x_test)

# %% [markdown]
# **Predictions and Evaluations**

# %%
print(classification_report(y_test,y_pred_rfc))
print(confusion_matrix(y_test,y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2408
#            1       0.42      0.02      0.03       466
#
#     accuracy                           0.84      2874
#    macro avg       0.63      0.51      0.47      2874
# weighted avg       0.77      0.84      0.77      2874
#
# [[2397   11]
#  [ 458    8]]
